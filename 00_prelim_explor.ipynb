# %%
import requests 
import pandas as pd 
import time
import numpy as np
import os

# %%
# define the header
headers = {'user-agent': os.environ.get("ONS-USER-AGENT")}

# define requets workflow
def requests_get(url):
    print(f"requesting {url}")
    try:
        response = requests.get(url,headers = headers)
        if response.status_code != 200:
            print(f"An error occured parsing content in the url: error {response.status_code}")
            return None
        else:
            return response
    except:
        print("System error with the `requests` module")
        return None

# %% [markdown]
# ## 1. Explore the data set available

# %%
# loading the datasets available
url = "https://api.beta.ons.gov.uk/v1/datasets"
res = requests.get(url, "html.parser")

# parse the result as a dataframe
df = pd.json_normalize(res.json()['items'], max_level=10)
df.columns
# Out:
# Index(['contacts', 'description', 'id', 'keywords', 'methodologies',
#        'national_statistic', 'next_release', 'related_datasets',
#        'release_frequency', 'state', 'title', 'unit_of_measure',
#        'links.editions.href', 'links.latest_version.href',
#        'links.latest_version.id', 'links.self.href', 'links.taxonomy.href',
#        'qmi.href', 'type', 'publications'],
#       dtype='object')

# %%
# parse the title of the datasets into a list
thematics = list(df.title)
thematics
# Out:
# ['Quarterly personal well-being estimates',
#  'Personal well-being estimates by local authority',
#  'Deaths registered weekly in England and Wales by region',
#  'Death registrations and occurrences by local authority and place of death',
#  'Death registrations and occurrences by health board and place of death',
#  'Deaths registered weekly in England and Wales by age and sex',
#  'UK spending on credit and debit cards',
#  'UK Business: Activity, Size and Location',
#  'Traffic Camera Activity',
#  'Trade in goods: country by commodity',
#  'Effects of Taxes and Benefits on Household Income',
#  'Suicide registrations in England and Wales by local authority',
#  'Sexual orientation by English regions and UK countries',
#  'Sexual orientation by age and sex',
#  'Retail sales index - large and small businesses',
#  'Retail sales index - all businesses',
#  'Retail sales index',
#  'Annual GDP for England, Wales and the English regions',
#  'Quarterly GDP for England, Wales and the English regions',
#  'Local authority ageing statistics, projected sex ratios for older people']

# %% [markdown]
# ## 2. GDP Data Set
# In this section, we try to look into the **Regional GDP** dataset.
#
# While the following code attemps to retrieve the full dataset using the API developed by the ONS, this is a much laborious process due to its limitation. If your intention is to acquire the full dataset, it is recommended that you download the `.csv` file directly.
# For this particular dataset, the link to the `.csv` file is enclosed in the API response of:
# https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6.
# Under the key `download`, it listed out 3 files that are available for download:
# * Observation dataset in `.csv` format
# * Observation dataset in `.xls` format
# * Meta data in `.csv` format

# %% [markdown]
# ### 2.1 Exploration of Structure
# Before writing a valid query string, we need to understand the structure of the API query.

# %%
# subset rows that contains gdp
gdp = df[df['title'].str.contains("GDP")].reset_index(drop = True)
gdp["links.editions.href"].values
# Out:
# array(['https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions',
#        'https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-quarter/editions'],
#       dtype=object)

# %%
# request the annual gdp meta data
url = gdp.loc[0,"links.editions.href"]
res_wb = requests_get(url)

# parse meta data as a pd DataFrame
annual_gdp_links = pd.json_normalize(res_wb.json()['items'], max_level=2)

# extract and inspect the href
href = [col for col in annual_gdp_links.columns if col.find("href") >0]
for col in href:
    print(annual_gdp_links[col].values)
# Out:
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions
# ['https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year']
# ['https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6']
# ['https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series']
# ['https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions']

# %%
# attempt for API request for observaiton and parse the dataframe
annual_gdp_df = "".join([annual_gdp_links.loc[0,href[1]],"/observations"])
annual_gdp = requests_get(annual_gdp_df)
# Out:
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations
# An error occured parsing content in the url: error 400

# %% [markdown]
# Loading the above url with a browser, the API returns an error message:
# >missing query parameters for the following dimensions:
# >* time
# >* geography
# >* unofficialstandardindustrialclassification
# >* prices
# >* growthrate
#
# Hence, we need to take a step back to request for a list of arguments that is accepted for each parameter.
# * Alternatively,following the version link should return a result that contains a downlod csv link.

# %%
# request meta data
annual_gdp_meta = requests_get(annual_gdp_links.loc[0,href[1]])
# parse for the href for parameter code list
params = pd.json_normalize(annual_gdp_meta.json()['dimensions']).set_index('label')
# inspect the result 
params
# Out:
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6
#                                                                                  href  \
# label
# Time                                https://api.beta.ons.gov.uk/v1/code-lists/cale...
# Geography                              https://api.beta.ons.gov.uk/v1/code-lists/nuts
# Standard Industrial Classification  https://api.beta.ons.gov.uk/v1/code-lists/sic-...
# Prices                              https://api.beta.ons.gov.uk/v1/code-lists/type...
# Measure                             https://api.beta.ons.gov.uk/v1/code-lists/quar...
#
#                                                                  id  \
# label
# Time                                                 calendar-years
# Geography                                                      nuts
# Standard Industrial Classification                   sic-unofficial
# Prices                                               type-of-prices
# Measure                             quarterly-index-and-growth-rate
#
#                                                                           name
# label
# Time                                                                      time
# Geography                                                            geography
# Standard Industrial Classification  unofficialstandardindustrialclassification
# Prices                                                                  prices
# Measure                                                             growthrate

# %%
# Storing the code list
param_geocode = "https://api.beta.ons.gov.uk/v1/code-lists/nuts/editions/one-off/codes"
param_price = "https://api.beta.ons.gov.uk/v1/code-lists/type-of-prices/editions/one-off/codes"
param_rate = "https://api.beta.ons.gov.uk/v1/code-lists/quarterly-index-and-growth-rate/editions/one-off/codes"
param_class = "https://api.beta.ons.gov.uk/v1/code-lists/sic-unofficial/editions/one-off/codes"

# %%
# parsing the geocode
geocode = requests_get(param_geocode)
geocode = pd.json_normalize(geocode.json()["items"])

# parsing the price
pricecode = requests_get(param_price)
pricecode = pd.json_normalize(pricecode.json()["items"])

# parsing rate code
ratecode = requests_get(param_rate)
ratecode = pd.json_normalize(ratecode.json()['items'])

# parsing industrial classificaiton
classcode = requests_get(param_class)
classcode = pd.json_normalize(classcode.json()['items'])
# Out:
# requesting https://api.beta.ons.gov.uk/v1/code-lists/nuts/editions/one-off/codes
# requesting https://api.beta.ons.gov.uk/v1/code-lists/type-of-prices/editions/one-off/codes
# requesting https://api.beta.ons.gov.uk/v1/code-lists/quarterly-index-and-growth-rate/editions/one-off/codes
# requesting https://api.beta.ons.gov.uk/v1/code-lists/sic-unofficial/editions/one-off/codes

# %%
# instantiate an empty dataframe
df = pd.DataFrame(columns = ['year','area','price','rate','industry','value'])

#
for year in range(2012,2024):
    for geo in geocode.code:
        for price in pricecode.code:
            for rate in ratecode.code:
                url = f"https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/\
                        time-series/versions/6/observations?\
                        time={year}&geography={geo}&unofficialstandardindustrialclassification=*\
                        &prices={price}&growthrate={rate}".replace(" ","")
                try:
                    response = requests_get(url)
                    observe = response.json()['observations']
                    time.sleep(0.5)
                    if observe is not None:
                        new_data = pd.json_normalize(observe)[['observation','dimensions.UnofficialStandardIndustrialClassification.id']]
                        new_data = new_data.rename(columns = {'observation':'value',
                                    'dimensions.UnofficialStandardIndustrialClassification.id':'industry'})
                    else:
                        print("0 observation under this parameterization")
                        continue
                except:
                    print('Error occured when parsing the API result to a pd DataFrame')
                    pass
                
                # fill na value
                new_data = new_data.replace("", pd.NA)

                # add column for each attribute
                col = len(new_data)
                new_data["year"] = [str(year) for _ in range(col)]
                new_data["area"] = [geo for _ in range(col)]
                new_data["price"] = [price for _ in range(col)]
                new_data["rate"] = [rate for _ in range(col)]

                # add to the dataframe
                df = pd.concat([df, new_data], ignore_index= True)
                print(f"{new_data['value'].count()} data points added")
# Out:
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=2017-prices&growthrate=aix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=2017-prices&growthrate=gra
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=2017-prices&growthrate=grq
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=2017-prices&growthrate=grqa
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=2017-prices&growthrate=qix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=chained-volume-measures-in-2016-money-value&growthrate=aix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=chained-volume-measures-in-2016-money-value&growthrate=gra
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=chained-volume-measures-in-2016-money-value&growthrate=grq
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=chained-volume-measures-in-2016-money-value&growthrate=grqa
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=chained-volume-measures-in-2016-money-value&growthrate=qix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=chained-volume-measures-index&growthrate=aix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=chained-volume-measures-index&growthrate=gra
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=chained-volume-measures-index&growthrate=grq
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=chained-volume-measures-index&growthrate=grqa
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=chained-volume-measures-index&growthrate=qix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=compensation-of-employees-by-industry-at-current-basic-prices&growthrate=aix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=compensation-of-employees-by-industry-at-current-basic-prices&growthrate=gra
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=compensation-of-employees-by-industry-at-current-basic-prices&growthrate=grq
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=compensation-of-employees-by-industry-at-current-basic-prices&growthrate=grqa
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=compensation-of-employees-by-industry-at-current-basic-prices&growthrate=qix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=cp&growthrate=aix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=cp&growthrate=gra
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=cp&growthrate=grq
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=cp&growthrate=grqa
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=cp&growthrate=qix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=current-price-estimates&growthrate=aix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=current-price-estimates&growthrate=gra
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=current-price-estimates&growthrate=grq
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=current-price-estimates&growthrate=grqa
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=current-price-estimates&growthrate=qix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=current-prices&growthrate=aix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=current-prices&growthrate=gra
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=current-prices&growthrate=grq
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=current-prices&growthrate=grqa
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=current-prices&growthrate=qix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=cvm&growthrate=aix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=cvm&growthrate=gra
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=cvm&growthrate=grq
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=cvm&growthrate=grqa
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=cvm&growthrate=qix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=cvmpub&growthrate=aix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=cvmpub&growthrate=gra
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=cvmpub&growthrate=grq
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=cvmpub&growthrate=grqa
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=cvmpub&growthrate=qix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-at-current-market-prices&growthrate=aix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-at-current-market-prices&growthrate=gra
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-at-current-market-prices&growthrate=grq
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-at-current-market-prices&growthrate=grqa
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-at-current-market-prices&growthrate=qix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-annual-growth-rates&growthrate=aix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-annual-growth-rates&growthrate=gra
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-annual-growth-rates&growthrate=grq
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-annual-growth-rates&growthrate=grqa
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-annual-growth-rates&growthrate=qix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-in-2016-money-value&growthrate=aix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-in-2016-money-value&growthrate=gra
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-in-2016-money-value&growthrate=grq
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-in-2016-money-value&growthrate=grqa
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-in-2016-money-value&growthrate=qix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-in-2018-money-value&growthrate=aix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-in-2018-money-value&growthrate=gra
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-in-2018-money-value&growthrate=grq
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-in-2018-money-value&growthrate=grqa
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-in-2018-money-value&growthrate=qix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-index&growthrate=aix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-index&growthrate=gra
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-index&growthrate=grq
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-index&growthrate=grqa
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-index&growthrate=qix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-per-head&growthrate=aix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-per-head&growthrate=gra
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-per-head&growthrate=grq
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-per-head&growthrate=grqa
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-per-head&growthrate=qix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-per-head-annual-growth-rates&growthrate=aix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-per-head-annual-growth-rates&growthrate=gra
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-per-head-annual-growth-rates&growthrate=grq
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-per-head-annual-growth-rates&growthrate=grqa
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-per-head-annual-growth-rates&growthrate=qix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-per-head-at-current-market-prices&growthrate=aix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-per-head-at-current-market-prices&growthrate=gra
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-per-head-at-current-market-prices&growthrate=grq
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-per-head-at-current-market-prices&growthrate=grqa
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-per-head-at-current-market-prices&growthrate=qix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-trading-profits-by-industry-at-current-basic-prices&growthrate=aix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-trading-profits-by-industry-at-current-basic-prices&growthrate=gra
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-trading-profits-by-industry-at-current-basic-prices&growthrate=grq
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-trading-profits-by-industry-at-current-basic-prices&growthrate=grqa
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-trading-profits-by-industry-at-current-basic-prices&growthrate=qix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-trading-surplus-by-industry-at-current-basic-prices&growthrate=aix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-trading-surplus-by-industry-at-current-basic-prices&growthrate=gra
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-trading-surplus-by-industry-at-current-basic-prices&growthrate=grq
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-trading-surplus-by-industry-at-current-basic-prices&growthrate=grqa
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-trading-surplus-by-industry-at-current-basic-prices&growthrate=qix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-value-added-annual-growth-rates&growthrate=aix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-value-added-annual-growth-rates&growthrate=gra
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-value-added-annual-growth-rates&growthrate=grq
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-value-added-annual-growth-rates&growthrate=grqa
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK&unofficialstandardindustrialclassification=*&prices=gross-value-added-annual-growth-rates&growthrate=qix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=2017-prices&growthrate=aix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=2017-prices&growthrate=gra
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=2017-prices&growthrate=grq
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=2017-prices&growthrate=grqa
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=2017-prices&growthrate=qix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=chained-volume-measures-in-2016-money-value&growthrate=aix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=chained-volume-measures-in-2016-money-value&growthrate=gra
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=chained-volume-measures-in-2016-money-value&growthrate=grq
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=chained-volume-measures-in-2016-money-value&growthrate=grqa
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=chained-volume-measures-in-2016-money-value&growthrate=qix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=chained-volume-measures-index&growthrate=aix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=chained-volume-measures-index&growthrate=gra
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=chained-volume-measures-index&growthrate=grq
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=chained-volume-measures-index&growthrate=grqa
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=chained-volume-measures-index&growthrate=qix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=compensation-of-employees-by-industry-at-current-basic-prices&growthrate=aix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=compensation-of-employees-by-industry-at-current-basic-prices&growthrate=gra
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=compensation-of-employees-by-industry-at-current-basic-prices&growthrate=grq
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=compensation-of-employees-by-industry-at-current-basic-prices&growthrate=grqa
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=compensation-of-employees-by-industry-at-current-basic-prices&growthrate=qix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=cp&growthrate=aix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=cp&growthrate=gra
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=cp&growthrate=grq
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=cp&growthrate=grqa
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=cp&growthrate=qix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=current-price-estimates&growthrate=aix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=current-price-estimates&growthrate=gra
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=current-price-estimates&growthrate=grq
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=current-price-estimates&growthrate=grqa
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=current-price-estimates&growthrate=qix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=current-prices&growthrate=aix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=current-prices&growthrate=gra
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=current-prices&growthrate=grq
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=current-prices&growthrate=grqa
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=current-prices&growthrate=qix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=cvm&growthrate=aix
# 23 data points added
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=cvm&growthrate=gra
# 0 data points added
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=cvm&growthrate=grq
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=cvm&growthrate=grqa
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=cvm&growthrate=qix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=cvmpub&growthrate=aix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=cvmpub&growthrate=gra
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=cvmpub&growthrate=grq
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=cvmpub&growthrate=grqa
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=cvmpub&growthrate=qix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-at-current-market-prices&growthrate=aix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-at-current-market-prices&growthrate=gra
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-at-current-market-prices&growthrate=grq
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-at-current-market-prices&growthrate=grqa
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-at-current-market-prices&growthrate=qix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-annual-growth-rates&growthrate=aix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-annual-growth-rates&growthrate=gra
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-annual-growth-rates&growthrate=grq
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-annual-growth-rates&growthrate=grqa
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-annual-growth-rates&growthrate=qix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-in-2016-money-value&growthrate=aix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-in-2016-money-value&growthrate=gra
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-in-2016-money-value&growthrate=grq
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-in-2016-money-value&growthrate=grqa
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-in-2016-money-value&growthrate=qix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-in-2018-money-value&growthrate=aix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-in-2018-money-value&growthrate=gra
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-in-2018-money-value&growthrate=grq
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-in-2018-money-value&growthrate=grqa
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-in-2018-money-value&growthrate=qix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UK0&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-index&growthrate=aix
# 0 observation under this parameterization
# ...
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=current-price-estimates&growthrate=aix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=current-price-estimates&growthrate=gra
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=current-price-estimates&growthrate=grq
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=current-price-estimates&growthrate=grqa
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=current-price-estimates&growthrate=qix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=current-prices&growthrate=aix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=current-prices&growthrate=gra
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=current-prices&growthrate=grq
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=current-prices&growthrate=grqa
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=current-prices&growthrate=qix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=cvm&growthrate=aix
# 23 data points added
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=cvm&growthrate=gra
# 0 data points added
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=cvm&growthrate=grq
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=cvm&growthrate=grqa
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=cvm&growthrate=qix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=cvmpub&growthrate=aix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=cvmpub&growthrate=gra
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=cvmpub&growthrate=grq
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=cvmpub&growthrate=grqa
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=cvmpub&growthrate=qix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-at-current-market-prices&growthrate=aix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-at-current-market-prices&growthrate=gra
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-at-current-market-prices&growthrate=grq
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-at-current-market-prices&growthrate=grqa
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-at-current-market-prices&growthrate=qix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-annual-growth-rates&growthrate=aix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-annual-growth-rates&growthrate=gra
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-annual-growth-rates&growthrate=grq
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-annual-growth-rates&growthrate=grqa
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-annual-growth-rates&growthrate=qix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-in-2016-money-value&growthrate=aix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-in-2016-money-value&growthrate=gra
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-in-2016-money-value&growthrate=grq
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-in-2016-money-value&growthrate=grqa
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-in-2016-money-value&growthrate=qix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-in-2018-money-value&growthrate=aix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-in-2018-money-value&growthrate=gra
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-in-2018-money-value&growthrate=grq
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-in-2018-money-value&growthrate=grqa
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-in-2018-money-value&growthrate=qix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-index&growthrate=aix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-index&growthrate=gra
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-index&growthrate=grq
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-index&growthrate=grqa
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-index&growthrate=qix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-per-head&growthrate=aix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-per-head&growthrate=gra
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-per-head&growthrate=grq
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-per-head&growthrate=grqa
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-per-head&growthrate=qix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-per-head-annual-growth-rates&growthrate=aix
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-per-head-annual-growth-rates&growthrate=gra
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-per-head-annual-growth-rates&growthrate=grq
# 0 observation under this parameterization
# requesting https://api.beta.ons.gov.uk/v1/datasets/regional-gdp-by-year/editions/time-series/versions/6/observations?time=2012&geography=UKJ&unofficialstandardindustrialclassification=*&prices=gross-domestic-product-chained-volume-measures-per-head-annual-growth-rates&growthrate=grqa
